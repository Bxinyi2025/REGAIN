# %% [markdown]
# ## This is a tutorial for a pre-trained HE encoder.

# %%
import os
import zipfile
from pathlib import Path

# %% [markdown]
# ### The test data in the data_demo folder.

# %%
import os
rootpath = os.getcwd()
workpath = os.path.join(rootpath, "..")
os.chdir(workpath)

# %%
data_dir = Path("data_demo")

# %% [markdown]
# ### Config file
#
# Parameters are defined in a config file (``./configs/config_demo.json`` for this demo). Important parameters include:
#
# - ``text_model_base_path``: Pre-trained visual-omics foundation model path.
# - ``data_sources_train_val``: Training data path.

# %% [markdown]
# ### pretrain
#
#
# - ``--config_file`` path to config file
# - ``--resume_epoch`` specifies whether to train from scratch or resume from a checkpoint, e.g., ``--resume_epoch 10`` to resume from the saved checkpoint from epoch 10. Set to 0 for training from scratch. Training will end when epoch number reaches `total_epochs` specified in the config file.
# - ``--gpu_id`` which GPU to use (0, 1, 2...)

# %%
# !python pretrain.py --config_file configs/config_demo.json --resume_epoch 0 --fold_id 1 --gpu_id 0

# %% [markdown]
# A folder is created under `./experiments/data_demo` where model checkpoints and outputs will be saved.
